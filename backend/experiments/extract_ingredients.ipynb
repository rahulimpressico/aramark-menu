# %%
! uv add ingredient_parser_nlp
! pip install ingredient-parser-nlp
# Out:
# Resolved 194 packages in 0.53ms
# Audited 87 packages in 0.06ms
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 23.4 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [ingredient-parser-nlp]/5 [ingredient-parser-nlp]
# ...
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
from ingredient_parser import parse_ingredient

ingredient_description = [
          "FLOUR ALL-PURPOSE",
          "BAKING POWDER",
          "EGG LIQUID CHOLESTEROL FREE FF FRESH CAGE FREE / COOKED",
          "JUICE BULK LEMON PASTEURIZED REFRIGERATED",
          "MILK BULK 2%",
          "SUGAR GRANULATED EXTRA FINE"
        ]

for ingredient in ingredient_description:
    parsed_ingredient = parse_ingredient(ingredient)
    msg = f"{parsed_ingredient.sentence} >> {parsed_ingredient.name[0].text} {parsed_ingredient.name[0].confidence}"
    print(msg)
# Out:
# FLOUR ALL-PURPOSE >> FLOUR ALL-PURPOSE 0.82193
# BAKING POWDER >> BAKING POWDER 0.99693
# EGG LIQUID CHOLESTEROL FREE FF FRESH CAGE FREE / COOKED >> EGG LIQUID CHOLESTEROL FREE FF FRESH CAGE FREE/COOKED 0.956922
# JUICE BULK LEMON PASTEURIZED REFRIGERATED >> JUICE BULK LEMON PASTEURIZED REFRIGERATED 0.997008
# MILK BULK 2% >> MILK BULK 2% 0.98647
# SUGAR GRANULATED EXTRA FINE >> SUGAR GRANULATED EXTRA FINE 0.997822
